# %% [markdown]
# # GenAI Sprint Lab Notebook
# *(Beginner → Intermediate)*
#
# ### Duration:
# 7 Days
#
# ---
#
# ### Learning Goals:
# By the end of this lab, you will be able to:
#
# - Choose the right AI model
# - Write effective prompts
# - Build GenAI apps using APIs
# - Understand text generation concepts
# - Create a mini AI project
#
# ---
#
# ### Weekly Plan:
#
# | Day | Topic | Outcome |
# |-----|------|--------|
# | Day 1 | Setup + GenAI Basics | Run first AI model |
# | Day 2 | Tokenization & Prompts | Understand tokens |
# | Day 3 | Working with LLMs | Summarization |
# | Day 4 | RAG Fundamentals | Retrieval system |
# | Day 5 | Mini RAG App | Q&A system |
# | Day 6 | GAN Basics | Image concepts |
# | Day 7 | Final Project | Complete project |

# %% [markdown]
# ## Section 0: Foundation + Setup (Day 1)
#
# ### GENAI Foundations + Model Landscape
#
# #### Topics Covered:
# - What is Generative AI?
# - Types of AI models
# - API-based vs Local models
# - Free model ecosystem
# - Model comparison basics

# %% [markdown]
# ### Task:
# - Install required libraries
# - Add API key
# - Test AI connection

# %%
# !pip uninstall -y google-generativeai
# !pip install -q google-genai
# Out:
# Found existing installation: google-generativeai 0.8.6
# Uninstalling google-generativeai-0.8.6:
#   Successfully uninstalled google-generativeai-0.8.6

# %%
import google.generativeai as genai

# TODO: Add your API key here
genai.configure(api_key="YOUR_API_KEY_HERE")

model = genai.GenerativeModel("gemini-3.1-flash-lite-preview")

response = model.generate_content("Say hello Maryam!")
print(response.text)
# Out:
# Hello Maryam! How are you doing today?

# %% [markdown]
# ### Explanation:
#
# - We connected to the Gemini API using an API key
# - We loaded a generative model
# - We sent a prompt to the model
# - The model generated a human-like response
#
# ---
#
# ### Key Concept:
# Generative AI works by predicting the next word based on patterns learned from data.

# %%
response = model.generate_content(
    "Explain Artificial Intelligence in 3 simple bullet points"
)

print(response.text)
# Out:
# Here is artificial intelligence explained in three simple points:
#
# *   **Learning from Data:** Instead of following a strict list of programmed rules, AI looks at massive amounts of information to find patterns and teach itself how to solve problems.
# *   **Mimicking Human Tasks:** It is designed to perform "smart" jobs that usually require a human brain, such as understanding speech, recognizing images, making decisions, or translating languages.
# *   **Improving Over Time:** The more data AI processes, the better it gets at its job, allowing it to become more accurate and helpful the longer it is used.

# %% [markdown]
# ### Reflection:
#
# - The model successfully generated responses
# - It understands natural language prompts
# - Output quality depends on prompt clarity
#
# ---
#
# ### Conclusion:
# This step confirms that our AI system is working correctly.

# %% [markdown]
# ## Section 1 — Tokenization Lab (Day 2)
#
# ### Objective:
# - Understand what tokens are
# - Convert text into tokens
# - Compare different tokenizers
#
# ---
#
# ### What is Tokenization?
#
# Tokenization is the process of breaking text into smaller pieces called **tokens**.
#
# Example:
# "AI is powerful" → ["AI", "is", "powerful"]

# %% [markdown]
# ### Tasks:
# - Tokenize text using BERT tokenizer
# - Count number of tokens
# - Compare with GPT-style tokenization

# %%
# !pip install -q transformers

# %%
from transformers import AutoTokenizer

# %% [markdown]
# ## Step 1: BERT Tokenization
#
# We will use a BERT tokenizer to split text into tokens.

# %%
text = "Generative AI is transforming education."

tokenizer_bert = AutoTokenizer.from_pretrained("bert-base-uncased")

tokens_bert = tokenizer_bert.tokenize(text)

print("BERT Tokens:", tokens_bert)
print("Token Count:", len(tokens_bert))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# BERT Tokens: ['genera', '##tive', 'ai', 'is', 'transforming', 'education', '.']
# Token Count: 7

# %% [markdown]
# ## Step 2: GPT-style Tokenization
#
# Now we simulate GPT-style tokenization using another tokenizer.

# %%
tokenizer_gpt = AutoTokenizer.from_pretrained("gpt2")

tokens_gpt = tokenizer_gpt.tokenize(text)

print("GPT Tokens:", tokens_gpt)
print("Token Count:", len(tokens_gpt))
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# GPT Tokens: ['Gener', 'ative', 'ĠAI', 'Ġis', 'Ġtransforming', 'Ġeducation', '.']
# Token Count: 7

# %% [markdown]
# ## Comparison
#
# ### Observations:
# - Different models break text differently
# - BERT uses subword tokenization
# - GPT uses byte-pair encoding
#
# ---
#
# ### Why it matters:
# - Token count affects cost (API usage)
# - Tokenization affects model understanding

# %%
new_text = "AI is changing the future of learning."

print("\n--- BERT ---")
print(tokenizer_bert.tokenize(new_text))

print("\n--- GPT ---")
print(tokenizer_gpt.tokenize(new_text))
# Out:
# --- BERT ---
# ['ai', 'is', 'changing', 'the', 'future', 'of', 'learning', '.']
#
# --- GPT ---
# ['AI', 'Ġis', 'Ġchanging', 'Ġthe', 'Ġfuture', 'Ġof', 'Ġlearning', '.']

# %% [markdown]
# ## Reflection
#
# ### Which tokenizer produced more tokens?
# Usually, BERT produces more tokens because it splits words into smaller subwords.
#
# ---
#
# ### Key Learning:
# - Tokenization is the first step in NLP
# - Different models process text differently
# - Efficient tokenization improves performance
#
# ---
#
# ### Conclusion:
# Understanding tokens helps in optimizing prompts and reducing API cost.

# %% [markdown]
# ## Section 2 — Working with LLMs (Day 3)
#
# ### Objective:
# - Use an LLM for text summarization
# - Understand prompt engineering
# - Compare weak vs strong prompts
#
# ---
#
# ### What is an LLM?
#
# A Large Language Model (LLM) is an AI model that understands and generates human-like text.
#
# Examples:
# - Chatbots
# - Text summarizers
# - Code assistants

# %% [markdown]
# ### Tasks:
# - Generate summary using AI
# - Improve prompts
# - Compare outputs

# %%
import google.generativeai as genai

genai.configure(api_key="YOUR_API_KEY_HERE")

model = genai.GenerativeModel("gemini-3.1-flash-lite-preview")

# %% [markdown]
# ## Step 1: Basic Text Summarization
#
# We will summarize a paragraph using AI.

# %%
text = """
Artificial Intelligence (AI) is transforming many industries including healthcare, education, and finance.
It helps machines learn from data and make decisions. Machine learning and deep learning are key areas of AI.
"""

prompt = "Summarize this text:\n" + text

response = model.generate_content(prompt)

print(response.text)
# Out:
# Artificial Intelligence, driven by machine learning and deep learning, is a transformative technology that enables machines to learn from data and make decisions across various sectors like healthcare, education, and finance.

# %% [markdown]
# ## Step 2: Improved Prompt (Better Output)
#
# Now we improve the prompt for better results.

# %%
better_prompt = """
You are an expert writer.
Summarize the following text in 3 clear bullet points:

""" + text

response = model.generate_content(better_prompt)

print(response.text)
# Out:
# Here is the summary:
#
# *   Artificial Intelligence is driving significant transformation across major sectors like healthcare, education, and finance.
# *   The core function of AI is enabling machines to learn from data to inform decision-making processes.
# *   Machine learning and deep learning serve as the foundational pillars of AI technology.

# %% [markdown]
# ## Step 3: Compare Prompts
#
# We compare a weak prompt vs a strong prompt.

# %%
bad_prompt = "Explain AI"
good_prompt = "Explain Artificial Intelligence in simple words with one real-life example."

res_bad = model.generate_content(bad_prompt)
res_good = model.generate_content(good_prompt)

print("Bad Prompt Output:\n", res_bad.text)
print("\n-------------------\n")
print("Good Prompt Output:\n", res_good.text)
# Out:
# ERROR:tornado.access:503 POST /v1beta/models/gemini-3.1-flash-lite-preview:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 7601.63ms
# Bad Prompt Output:
#  At its simplest, **Artificial Intelligence (AI)** is a field of computer science that builds systems capable of performing tasks that typically require human intelligence.
#
# Think of traditional computer programs as a **recipe**: you give the computer a strict set of instructions, and it follows them exactly. If the situation changes slightly, the program often fails.
#
# **AI is different because it learns.** Instead of following a rigid recipe, it looks at vast amounts of data, identifies patterns, and makes decisions or predictions based on those patterns.
#
# Here is a breakdown of how it works and why it matters:
#
# ---
#
# ### 1. How does AI work? (The core concepts)
# Most modern AI is built on a subset called **Machine Learning (ML)**. Here is the basic process:
# ...

# %% [markdown]
# ## Analysis
#
# ### Observations:
# - Bad prompts give vague answers
# - Good prompts give clear and structured answers
#
# ---
#
# ### Key Idea:
# Prompt = Instruction to AI
# Better instruction = Better output

# %%
creative_prompt = "Explain AI as if you are teaching a 10-year-old student."

response = model.generate_content(creative_prompt)

print(response.text)
# Out:
# Imagine you have a robot friend. Usually, if you want a computer to do something, you have to give it very strict, step-by-step instructions—like a recipe. If you miss one step, the computer gets confused.
#
# **Artificial Intelligence (AI) is different.** Instead of giving the computer a recipe, we give it a **ton of examples** and let it figure out the patterns itself.
#
# Here is how it works, broken down into three easy steps:
#
# ### 1. Learning by Example (Training)
# Imagine you want to teach a computer to recognize a dog. Instead of writing a rule like "must have floppy ears and a tail" (because some dogs have pointy ears and some have short tails!), you show the computer **thousands of pictures** of dogs.
#
# You tell the computer, "This is a dog," and "This is not a dog." Eventually, the computer starts to notice patterns—like the shape of a nose or the texture of fur—that humans might not even notice.
#
# ### 2. Making Guesses (Prediction)
# ...

# %% [markdown]
# ## Reflection
#
# ### What improved?
# - Output became clearer with better prompts
# - Structure and tone improved
#
# ---
#
# ### Key Learning:
# - Prompt engineering is very important
# - Small changes in prompt = big difference in output
#
# ---
#
# ### Conclusion:
# Good prompts make AI more useful and accurate.

# %% [markdown]
# ## Section 3 — RAG Fundamentals (Day 4)
#
# ### Objective:
# - Understand Retrieval Augmented Generation (RAG)
# - Learn embeddings concept
# - Perform basic vector search
#
# ---
#
# ### What is RAG?
#
# RAG = Retrieval + Generation
#
# It means:
# - First, retrieve relevant information
# - Then, generate an answer using that information
#
# ---
#
# ### Why RAG?
#
# - LLMs do not know real-time data
# - They may give incorrect answers (hallucination)
# - RAG provides accurate and updated context

# %% [markdown]
# ### Tasks:
# - Create sample documents
# - Convert text into embeddings
# - Perform similarity search

# %%
# !pip install -q sentence-transformers

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

# %% [markdown]
# ## Step 1: Create Sample Documents
#
# We define a small dataset to search from.

# %%
docs = [
    "Artificial Intelligence is the simulation of human intelligence.",
    "Machine Learning is a subset of AI that learns from data.",
    "Deep Learning uses neural networks for complex tasks.",
    "Natural Language Processing helps machines understand text."
]

# %% [markdown]
# ## Step 2: Convert Text into Embeddings
#
# Embeddings are numerical representations of text.

# %%
model_embed = SentenceTransformer("all-MiniLM-L6-v2")

doc_embeddings = model_embed.encode(docs)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ...

# %% [markdown]
# ## Step 3: Perform Vector Search
#
# We find the most relevant document based on a query.

# %%
query = "What is AI?"

query_embedding = model_embed.encode([query])

scores = np.dot(doc_embeddings, query_embedding.T)

best_index = np.argmax(scores)

print("Query:", query)
print("Most Relevant Document:", docs[best_index])
# Out:
# Query: What is AI?
# Most Relevant Document: Artificial Intelligence is the simulation of human intelligence.

# %% [markdown]
# ## Step 4: Generate Answer using Context
#
# Now we combine retrieval with AI generation.

# %%
context = docs[best_index]

prompt = f"""
Answer using the context below:

Context: {context}

Question: {query}
"""

response = model.generate_content(prompt)

print(response.text)
# Out:
# AI is the simulation of human intelligence.

# %% [markdown]
# ## Analysis
#
# ### What happened?
# - We retrieved the most relevant document
# - We used it as context for the AI
# - AI generated a more accurate answer
#
# ---
#
# ### Key Concept:
# RAG improves accuracy by adding external knowledge.

# %%
new_query = "What is machine learning?"

query_embedding = model_embed.encode([new_query])
scores = np.dot(doc_embeddings, query_embedding.T)
best_index = np.argmax(scores)

print("Query:", new_query)
print("Answer Source:", docs[best_index])
# Out:
# Query: What is machine learning?
# Answer Source: Machine Learning is a subset of AI that learns from data.

# %% [markdown]
# ## Reflection
#
# ### Benefits of RAG:
# - More accurate answers
# - Uses real data
# - Reduces hallucination
#
# ---
#
# ### Conclusion:
# RAG combines search + AI to improve response quality.

# %% [markdown]
# ## Section 4 — Build Mini RAG App (Day 5)
#
# ### Objective:
# - Build a small Question-Answer system
# - Use multiple documents
# - Combine search + AI generation
#
# ---
#
# ### What We Will Build:
# A simple system where:
# 1. User asks a question
# 2. System finds relevant documents
# 3. AI generates an answer using context

# %% [markdown]
# ### Tasks:
# - Add multiple documents
# - Create embeddings
# - Build query function
# - Generate answers

# %%
docs_extended = [
    "Artificial Intelligence (AI) refers to machines that can think and learn.",
    "Machine Learning (ML) allows systems to learn from data automatically.",
    "Deep Learning is a type of ML using neural networks.",
    "Natural Language Processing (NLP) helps computers understand human language.",
    "AI is used in healthcare, finance, education, and robotics.",
    "Chatbots use AI to communicate with users.",
    "Self-driving cars use AI to make decisions in real time.",
    "AI improves efficiency and automation in industries."
]

# %%
doc_embeddings_ext = model_embed.encode(docs_extended)

# %% [markdown]
# ## Step 3: Create Query Function
#
# This function will:
# - Take a user question
# - Find top relevant documents
# - Generate answer using AI

# %%
def rag_query(query_text, docs, embeddings):

    # Encode query
    query_embedding = model_embed.encode([query_text])

    # Similarity search
    scores = np.dot(embeddings, query_embedding.T)

    # Get top 2 documents
    top_indices = np.argsort(scores.flatten())[-2:]

    context = "\n".join([docs[i] for i in top_indices])

    # Create prompt
    prompt = f"""
    Answer the question using only the context below:

    Context:
    {context}

    Question: {query_text}
    """

    response = model.generate_content(prompt)

    return response.text

# %% [markdown]
# ## Step 4: Test the System
#
# We will ask questions and get AI-generated answers.

# %%
questions = [
    "What is AI?",
    "Where is AI used?",
    "What is machine learning?"
]

for q in questions:
    print("Question:", q)
    print("Answer:", rag_query(q, docs_extended, doc_embeddings_ext))
    print("-" * 50)
# Out:
# Question: What is AI?
# Answer: Artificial Intelligence (AI) refers to machines that can think and learn.
# --------------------------------------------------
# Question: Where is AI used?
# ERROR:tornado.access:503 POST /v1beta/models/gemini-3.1-flash-lite-preview:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 4714.28ms
# Answer: AI is used in healthcare, finance, education, and robotics.
# --------------------------------------------------
# Question: What is machine learning?
# Answer: Machine Learning (ML) allows systems to learn from data automatically.
# --------------------------------------------------

# %% [markdown]
# ## Analysis
#
# ### What happened?
# - System searched relevant documents
# - Used them as context
# - Generated accurate answers
#
# ---
#
# ### Key Idea:
# This is a simple version of ChatGPT-like systems.

# %%
def rag_query(query_text, docs, embeddings):

    import time

    query_embedding = model_embed.encode([query_text])
    scores = np.dot(embeddings, query_embedding.T)

    top_index = np.argmax(scores)
    context = docs[top_index]

    prompt = f"""
    Context:
    {context}

    Question: {query_text}

    Answer briefly:
    """

    for i in range(3):
        try:
            response = model.generate_content(prompt)
            time.sleep(2)
            return response.text
        except Exception as e:
            time.sleep(2)

    return "Error: Try again later"

# %% [markdown]
# ## Reflection
#
# ### Advantages:
# - Answers are more accurate
# - Uses real data
# - Flexible system
#
# ---
#
# ### Conclusion:
# Mini RAG system shows how modern AI assistants work.

# %% [markdown]
# ## Section 5 — GAN Fundamentals (Day 6)
#
# ### Objective:
# - Understand Generative Adversarial Networks (GANs)
# - Learn Generator vs Discriminator
# - Build a simple GAN structure
#
# ---
#
# ### What is a GAN?
#
# GAN = Generative Adversarial Network
#
# It consists of two models:
# 1. Generator → creates fake data
# 2. Discriminator → checks real vs fake
#
# ---
#
# ### Simple Idea:
# Generator tries to fool the Discriminator
# Discriminator tries to detect fake data
# Both improve over time

# %% [markdown]
# ## Generator vs Discriminator
#
# ### Generator:
# - Creates fake data (images, text, etc.)
# - Takes random noise as input
# - Learns to make realistic outputs
#
# ### Discriminator:
# - Acts like a judge
# - Classifies input as real or fake
# - Improves detection over time

# %%
# !pip install -q torch

# %%
import torch
import torch.nn as nn

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(10, 16),
            nn.ReLU(),
            nn.Linear(16, 8)
        )

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## Step 2: Discriminator Model
#
# This model checks whether data is real or fake.

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(8, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## Step 3: Test GAN Models
#
# We generate fake data and pass it through the discriminator.

# %%
# Create models
gen = Generator()
disc = Discriminator()

# Generate random noise
noise = torch.randn(1, 10)

# Generate fake data
fake_data = gen(noise)

# Discriminator decision
decision = disc(fake_data)

print("Fake Data:", fake_data)
print("Discriminator Output:", decision)
# Out:
# Fake Data: tensor([[-0.1260,  0.1093, -0.0841, -0.0177, -0.2674,  0.0422, -0.2808,  0.0207]],
#        grad_fn=<AddmmBackward0>)
# Discriminator Output: tensor([[0.4327]], grad_fn=<SigmoidBackward0>)

# %% [markdown]
# ## Explanation
#
# ### Process:
# 1. Generator creates fake data
# 2. Discriminator evaluates it
# 3. Output shows probability of being real
#
# ---
#
# ### Key Idea:
# GANs learn by competition between two networks.

# %%
# Generate multiple fake samples
for i in range(3):
    noise = torch.randn(1, 10)
    fake = gen(noise)
    print(f"Sample {i+1}:", fake)
# Out:
# Sample 1: tensor([[-0.0321, -0.2563, -0.1507, -0.1570,  0.3538, -0.1673, -0.4126,  0.1262]],
#        grad_fn=<AddmmBackward0>)
# Sample 2: tensor([[-0.4340,  0.1171,  0.3794,  0.6715, -0.2962, -0.1235,  0.2247, -0.1884]],
#        grad_fn=<AddmmBackward0>)
# Sample 3: tensor([[ 0.2765,  0.1574,  0.2596, -0.2955, -0.0371,  0.1523, -0.1991,  0.0908]],
#        grad_fn=<AddmmBackward0>)

# %% [markdown]
# ## Reflection
#
# ### Why GANs are useful:
# - Generate realistic images
# - Create synthetic data
# - Used in AI art and deep learning
#
# ---
#
# ### Challenges:
# - Hard to train
# - Can produce poor quality outputs
#
# ---
#
# ### Conclusion:
# GANs are powerful but complex models used in advanced AI systems.

# %% [markdown]
# ## Section 6 — Final Mini Project (Day 7)
#
# ### Project Title:
# AI Text Analysis Tool
#
# ---
#
# ### Objective:
# Build a system that:
# - Takes input text
# - Counts tokens
# - Generates summary
# - Displays results
#
# ---
#
# ### Features:
# - Token counting
# - AI summarization
# - Clean output

# %% [markdown]
# ### Tasks:
# - Create token counter
# - Create summarization function
# - Combine both

# %%
from transformers import AutoTokenizer
import google.generativeai as genai

# %%
genai.configure(api_key="YOUR_API_KEY_HERE")

model = genai.GenerativeModel("gemini-1.5-flash")

# %% [markdown]
# ## Step 1: Token Counter
#
# We count tokens using a tokenizer.

# %%
def count_tokens(text):
    tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
    tokens = tokenizer.tokenize(text)
    return len(tokens), tokens

# %% [markdown]
# ## Step 2: Summarization Function
#
# We use AI to summarize text.

# %%
def summarize_text(text):
    prompt = "Summarize this text in simple words:\n" + text
    response = model.generate_content(prompt)
    return response.text

# %% [markdown]
# ## Step 3: Combine Functions
#
# Now we combine token counting and summarization.

# %%
def analyze_text(text):

    token_count, tokens = count_tokens(text)
    summary = summarize_text(text)

    return {
        "token_count": token_count,
        "summary": summary
    }

# %% [markdown]
# ## Step 4: Test the Project

# %%
# Install (run once)
# !pip install -q google-generativeai transformers

# Imports
import google.generativeai as genai
from transformers import AutoTokenizer

#  Add your NEW API key here
genai.configure(api_key="YOUR_API_KEY_HERE")

#  Load Gemini model
model = genai.GenerativeModel("gemini-3.1-flash-lite-preview")

#  Token Counter
def count_tokens(text):
    tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
    tokens = tokenizer.tokenize(text)
    return len(tokens)

#  Summarization
def summarize_text(text):
    try:
        response = model.generate_content(
            "Summarize this text in simple words:\n" + text
        )
        return response.text
    except:
        return "Error: Check API key or quota."

#  Main Function
def analyze_text(text):
    token_count = count_tokens(text)
    summary = summarize_text(text)
    return token_count, summary

#  Test Input
sample_text = """
Artificial Intelligence is a powerful technology that allows machines to learn from data.
It is used in many fields like healthcare, education, and finance.
"""

#  Run
tokens, summary = analyze_text(sample_text)

print("Token Count:", tokens)
print("\nSummary:\n", summary)
# Out:
# Token Count: 28
#
# Summary:
#  Artificial Intelligence helps machines learn from information. It is used in many areas, such as medicine, schools, and banking.

# %% [markdown]
# ## Final Reflection
#
# ### What we built:
# - A complete AI text analysis tool
# - Combined tokenization + AI
#
# ---
#
# ### Key Learning:
# - Multiple AI concepts can be integrated
# - Prompt design affects output
# - Tokenization helps in optimization
#
# ---
#
# ### Conclusion:
# This project demonstrates a simple real-world AI application.

# %% [markdown]
# ## Deliverables
#
# - Completed notebook
# - Tokenization output
# - Summarization working
# - Final project output
