# %% [markdown]
# # Deep Learning Assignment
#
# ## Handwritten Digit Recognition using Neural Networks (MNIST)
#
# **Student Name:** Maryam Fatima
# **Course:** Deep Learning
# **Week:** 8
#
# ---
#
# ### 📌 Objective
#
# This notebook explains the basics of Deep Learning, Neural Networks, and Computer Vision.
# It also demonstrates building a Neural Network model for digit classification using MNIST dataset.
#
# ---

# %% [markdown]
# ## 📖 Introduction to Deep Learning
#
# Deep Learning is a part of Machine Learning that uses neural networks with multiple layers.
#
# It is used in:
#
# * Image recognition
# * Speech recognition
# * AI systems
#
# Deep learning models automatically learn features from data.
#
# ---

# %% [markdown]
# ## 🧠 Neural Network Fundamentals

# %% [markdown]
# A Neural Network is made of layers:
#
# * Input Layer
# * Hidden Layer
# * Output Layer
#
# It learns patterns from data.
#
# ---

# %% [markdown]
# A neuron:
#
# * Takes input
# * Multiplies with weights
# * Adds bias
# * Applies activation function
#
# ---

# %%
import numpy as np

inputs = np.array([1, 2, 3])
weights = np.array([0.5, -0.2, 0.3])
bias = 0.4

output = np.dot(inputs, weights) + bias

def step(x):
    return 1 if x > 0 else 0

print(step(output))
# Out:
# 1

# %% [markdown]
# Backpropagation is used to train neural networks.
#
# Steps:
#
# 1. Prediction
# 2. Error
# 3. Update weights
#
# ---

# %%
import numpy as np

X = np.array([[0.5, 0.2]])
y = np.array([[1]])

np.random.seed(1)
W = np.random.rand(2, 1)
b = np.random.rand(1)

def sigmoid(x):
    return 1/(1+np.exp(-x))

def sigmoid_derivative(x):
    return x*(1-x)

for i in range(1000):

    z = np.dot(X, W) + b
    output = sigmoid(z)

    error = y - output

    d_output = error * sigmoid_derivative(output)

    W += np.dot(X.T, d_output) * 0.1
    b += np.sum(d_output) * 0.1

print("Final Output:", output)
# Out:
# Final Output: [[0.92967423]]

# %% [markdown]
# ANN has:
#
# * Input layer
# * Hidden layer
# * Output layer
#
# More layers = better learning
#
# ---

# %%
import numpy as np

X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[1],[1],[0]])

np.random.seed(1)

W1 = np.random.rand(2,3)
W2 = np.random.rand(3,1)

def sigmoid(x):
    return 1/(1+np.exp(-x))

for i in range(5000):

    # Forward
    hidden = sigmoid(np.dot(X, W1))
    output = sigmoid(np.dot(hidden, W2))

    # Error
    error = y - output

    # Backprop
    d_output = error * (output*(1-output))
    d_hidden = d_output.dot(W2.T) * (hidden*(1-hidden))

    # Update
    W2 += hidden.T.dot(d_output) * 0.1
    W1 += X.T.dot(d_hidden) * 0.1

print(output)
# Out:
# [[0.49292026]
#  [0.50085518]
#  [0.50556279]
#  [0.51063515]]

# %% [markdown]
# Data preprocessing means:
#
# * Cleaning data
# * Scaling values
# * Converting into proper format
#
# It improves model performance.
#
# ---

# %%
from sklearn.preprocessing import MinMaxScaler

data = [[100],[200],[300]]
scaler = MinMaxScaler()

scaled = scaler.fit_transform(data)

print(scaled)
# Out:
# [[0. ]
#  [0.5]
#  [1. ]]

# %% [markdown]
# Computer Vision allows machines to understand images.
#
# CNN is used for image tasks:
#
# * Image classification
# * Object detection
#
# Layers:
#
# * Convolution
# * Pooling
#
# ---

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2
)

# %% [markdown]
# Pretrained models are already trained on large datasets.
#
# Transfer learning:
#
# * Use existing model
# * Train on new data
#
# ---

# %%
from tensorflow.keras.applications import VGG16

model = VGG16(weights='imagenet')
# Out:
# ...
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Load data
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize
X_train = X_train / 255.0
X_test = X_test / 255.0

# Model
model = models.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compile
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train
model.fit(X_train, y_train, epochs=5)

# Evaluate
model.evaluate(X_test, y_test)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9264 - loss: 0.2565
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9675 - loss: 0.1123
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9766 - loss: 0.0779
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9822 - loss: 0.0589
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9862 - loss: 0.0452
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9744 - loss: 0.0843
# [0.08428467065095901, 0.974399983882904]
